# %%
import pandas as pd

import sqlite3
import pandas as pd

import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)


# Create db connection.
cnx = sqlite3.connect('data/database.sqlite')





seasons = ['2015/2016']
leagues_id = [1729]

# %%
## Cleaning names of teams

import stringdist

# Normalize names 
def normalize_team_names(y):
    teams = []
    for t in list(y):
        tt = t.lower().split()
        rem = []
        cont=0
        #print(tt)
        for el in tt:
            cont +=1
            if el in ['athletico','atletico','athlético','atlético','atl','ath','athletic']: 
                if cont < len(tt):
                    tt[cont]='atl'+tt[cont]
            if el in ['manchester','man','sporting','sp','deportivo','la','de','real','fc','cf','ud','las','cd','balompié','rc','de','athletico','atletico','athlético','atlético','atl','ath','athletic']:
                rem.append(el)
            
                #print(tt)
        if rem != []:
            for r in rem:
                tt.remove(r)
        
        if len(tt)>1:
            if len(tt[0])>len(tt[1]):
                t = tt[0]
            else:
                t = tt[1]
        else:
            t=tt[0]
        #print(t)  
        teams.append(t)
    return teams

#Change name x for the most similar name in the teams_normalized list.
def func(x,teams_normalized):
    dist =0
    distmin=10
    xt = x.lower().split()
    rem = []
    cont=0
    for el in xt:
        cont +=1
        if el in ['athletico','atletico','athlético','atlético','atl','ath','athletic']:
            if cont < len(xt):
                xt[cont]='atl'+xt[cont]
        if el in ['manchester','man','sporting','sp','deportivo','la','de','real','fc','cf','ud','las','cd','balompié','rc','de','athletico','atletico','athlético','atlético','atl','ath','athletic']:
            rem.append(el)
    if rem != []:
        for r in rem:
                xt.remove(r)
                


    if len(xt)>1:
        if len(xt[0])>len(xt[1]):
            x = xt[0]
        else:
            x = xt[1]
    else:
        x=xt[0]

    
    for t in list(teams_normalized):
        dist = stringdist.levenshtein(x, t)
        #print(t)
        if dist < distmin:
            #print('................')
            #print(x)
            #print(t)
            #print(dist)
            #print('................')
            distmin = dist
            team =t
    return team



def convert_to(df,type_to_convert, all_categorical = False,columns = 'None'):
 
    if all_categorical == True:
        categoric_types = df.select_dtypes(include=['object','category']).columns
        if categoric_types.empty:
            print('No object types in the dataframe to be converted')
            return df
        else:
            if 'labels' in categoric_types:
                categoric_types.remove('labels')
            df[categoric_types] = df[categoric_types].astype('category')
            columns = categoric_types
        
    else:
        df[columns] = df[columns].astype('category')
        
        
    if type_to_convert == 'labelling':
        for column in columns:
            df[column] = df[column].cat.codes
    elif type_to_convert == 'onehot':
        for column in columns:
            print(columns)
            df= pd.get_dummies(df, columns=[column])             
      
    return df

def convert_to_standard_team_names(cnx, league_id, season):

    #.......... df_matches ..........
    
    #Read matches from the season and league specified.
    df_matches = pd.read_sql_query("SELECT * FROM Match WHERE league_id = (?) AND season = (?)", cnx, params=(league_id,season,)) 
    print(f'The shape of df_matches of league:{league_id} and season:{season} is: {df_matches.shape}')

    #Drop columns with not useful information (html text), we will get this information from another dataset from football-data.co.uk
    df_matches = df_matches.drop(columns=['goal', 'shoton', 'shotoff','foulcommit', 'card', 'cross', 'corner', 'possession'])

    #Convert types
    df_matches['date'] = pd.to_datetime(df_matches['date'])
    df_matches['date'] = pd.to_datetime(df_matches['date'],format='%Y%m%d')
    df_matches['stage'] = df_matches['stage'].astype(int)
    
   #To merge data with the other dataset we need a common team id between both datasets. We are going to create a unique string identifier for team names named team_name_id.
    
    
    #In the df_matches we will first include a column with the name of the team extracted from the Team table by means of the team_api_id.
    df_Teams = pd.read_sql_query("SELECT * FROM Team ", cnx)
    df_Teams.head()
    

    # Manually change some names due its difficulty to be treated for our string name procedure.
    df_Teams.loc[df_Teams['team_long_name']=='Athletic Club de Bilbao','team_long_name'] = 'Athletic Bilbao'
    df_Teams.loc[df_Teams['team_long_name']=='Real Sporting de Gijón','team_long_name'] = 'Sporting Gijon'
    
    df_Teams.loc[df_Teams['team_long_name']=='West Bromwich Albion','team_long_name'] = 'West Brom'
    df_Teams.loc[df_Teams['team_long_name']=='West Ham United','team_long_name'] = 'West Ham'
    df_Teams.loc[df_Teams['team_long_name']=='Queens Park Rangers','team_long_name'] = 'QPR'
    df_Teams.loc[df_Teams['team_long_name']=='Stoke City','team_long_name'] = 'Stoke'
    df_Teams.loc[df_Teams['team_long_name']=='Hull City','team_long_name'] = 'Hull'
    df_Teams.loc[df_Teams['team_long_name']=='Bolton Wanderers','team_long_name'] = 'Bolton'
    df_Teams.loc[df_Teams['team_long_name']=='Wolverhampton Wanderers', 'team_long_name'] = 'Wolves'
    
    
    
    
    #First we normalize the names of the teams
    teams_normalized = normalize_team_names(df_Teams['team_long_name'])
    
    #Now we normalize the names of df_Teams 
    df_Teams['team_name_id']= df_Teams['team_long_name'].apply(lambda x: func(x,teams_normalized))

    
    #Now we will have to include names of the teams into de df_matches dataframe, for this we have to merge df_matches with df_Teams on the "team_api_id".
    #Since df_matches just have names of the 'home_team_api_id' and 'away_team_api_id', we will add a new column referring the corresponding teams as 'home_team_name_id' and 'away_team_name_id'.
    df_matches['home_team_name_id']=df_matches.merge(df_Teams[['team_api_id','team_name_id']], left_on='home_team_api_id', right_on='team_api_id',how='left')['team_name_id']
    df_matches['away_team_name_id']=df_matches.merge(df_Teams[['team_api_id','team_name_id']], left_on='away_team_api_id', right_on='team_api_id',how='left')['team_name_id']

    #We finally have the df_matches with the Match Table information but with the home_tema_name_id and away_team_name_id which will be useful to create a common id between the two csv that we want to merge.
    
    #print(df_Teams)
    

    
    #.......... footballdata ..........
    
    #Read matches from the season and league specified.
    location_to_file = 'data/'
    season_footdata = season.replace('/','_').replace('20','') 
    df_footballdata = pd.read_csv(location_to_file+'{0}_{1}.csv'.format(league_id,season_footdata))   
    print(f'The shape of df_footballdata of league:{league_id} and season:{season_footdata} is: {df_footballdata.shape}')
  
    #Convert types    
    df_footballdata['date'] = pd.to_datetime(df_footballdata['Date'])
    df_footballdata['date'] = pd.to_datetime(df_footballdata['date'], format='%Y%m%d')

    
    #Creating same names for teams as the other dataset
    df_footballdata['home_team_name_id'] = df_footballdata['HomeTeam'].apply(lambda x: func(x,teams_normalized))
    df_footballdata['away_team_name_id'] = df_footballdata['AwayTeam'].apply(lambda x: func(x,teams_normalized))
    
    
    
    
    #Creating common match identifier for both datasets (uid)
    df_footballdata['uid']= df_footballdata['home_team_name_id']+df_footballdata['away_team_name_id']
    df_matches['uid']= df_matches['home_team_name_id']+df_matches['away_team_name_id']
    
    return df_matches, df_footballdata

def merge_matchtable_footballdata(season,league_id):
    
    df_matches, df_footballdata = convert_to_standard_team_names(cnx, league_id, season)
    
#     print((df_matches[['home_team_name_id','away_team_name_id','uid']]))
     
#     print((df_footballdata[['home_team_name_id','away_team_name_id']]))

#     print((df_matches['uid'].sort_values(ascending=True)))
#     print((df_footballdata['uid'].sort_values(ascending=True)))
    
    if len(set(df_matches['uid']).symmetric_difference(set(df_footballdata['uid']))) > 0:
        print('Names of uid of both datasets do not match.')
        print('CAUTION!!!! THE FOLLOWING NAMES HAVE DIFFERENT SPELLING IN THE TWO DATASETS: ',
              set(df_matches['uid']).symmetric_difference(set(df_footballdata['uid'])))
    
    # Merging both datasets
    df_complete_league_year = pd.merge(df_matches, df_footballdata[['FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG',
       'HTR', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY','AY', 'HR', 'AR','uid']], on='uid', how='inner')
    
    print(f'df_complete_league_year shape: {df_complete_league_year.shape}')

    
    
    # Implementing models with Real Data as the guys from Stanford suggest.
    # We create the dataset as it is stated at: 
    # *Shin, JongHo and Robert Gasparyan. “A novel way to Soccer Match Prediction.” (2014).*
    
    #Sort per date.
    df_complete_league_year['date'] = pd.to_datetime(df_complete_league_year['date'])
    df_complete_league_year=df_complete_league_year.sort_values(by='date')

    #We keep just the data need it for this.
    df_matches_info = df_complete_league_year[['id','uid','date','stage','home_team_name_id','away_team_name_id','FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG',
       'HTR', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY','AY', 'HR', 'AR']]  
    df_matches_info[['FTHG', 'FTAG', 'HTHG', 'HTAG', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF','HC', 'AC', 'HY','AY', 'HR', 'AR']] = df_matches_info.loc[:,['FTHG', 'FTAG', 'HTHG', 'HTAG', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF','HC', 'AC', 'HY','AY', 'HR', 'AR']].astype(float)

    
    #Creating a column for the labels
    labels = df_matches_info["FTR"]
    df_matches_info = pd.get_dummies(df_matches_info, columns=["FTR", "HTR"])
    df_matches_info['labels'] = labels

    
    #Selecting features
    df_matches_infos = df_matches_info[['id','stage','date','home_team_name_id','away_team_name_id','labels','FTHG', 'FTAG', 'HTHG', 'HTAG', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF','HC', 'AC', 'HY','AY', 'HR', 'AR']]
    df_matches_infos = df_matches_info[['uid','id','stage','date','home_team_name_id','away_team_name_id','labels','FTHG', 'FTAG']]

   
    return df_matches_infos


datasets = []
for league_id in leagues_id:
    for season in seasons:
        dataset_season = merge_matchtable_footballdata(season,league_id)
        datasets.append(dataset_season.loc[:, :])
        
df_clustering = pd.concat(datasets)
# Out:
# The shape of df_matches of league:1729 and season:2015/2016 is: (380, 115)
# The shape of df_footballdata of league:1729 and season:15_16 is: (380, 65)
# df_complete_league_year shape: (380, 128)
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py:3140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %% [markdown]
# # Until here we have the origin dataset from which we are going to make the clustering

# %%
df_clustering.head()
# Out:
#                    uid    id  stage       date home_team_name_id  \
# 1     bournemouthvilla  4390      1 2015-08-08       bournemouth
# 2       chelseaswansea  4391      1 2015-08-08           chelsea
# 3       evertonwatford  4392      1 2015-08-08           everton
# 4  leicestersunderland  4393      1 2015-08-08         leicester
# 5      unitedtottenham  4394      1 2015-08-08            united
#
#   away_team_name_id labels  FTHG  FTAG
# 1             villa      A   0.0   1.0
# 2           swansea      D   2.0   2.0
# 3           watford      D   2.0   2.0
# 4        sunderland      H   4.0   2.0
# 5         tottenham      H   1.0   0.0

# %%
df_clustering['res']= df_clustering['FTHG']-df_clustering['FTAG']
# df_clustering['res'] = pd.cut(df_clustering['res'], 10)
# df_clustering.info()
# df_clustering.drop(columns=['FTHG','FTAG'])

def conv(s):
    if s >=3:
        return 'HP'
    elif s<3 and s>=1:
        return 'H'
    elif s<1 and s>-1:
        return 'D'
    elif s<=-1 and s>-3:
        return 'A'
    elif s<=-3: 
        return 'AP'
    
    


    
df_clustering['res']= df_clustering['res'].apply(lambda x: conv(x))    
df_clustering.head()    
df_clustering.drop(columns=['FTHG','FTAG'])
# Out:
#                         uid    id  stage       date home_team_name_id  \
# 1          bournemouthvilla  4390      1 2015-08-08       bournemouth
# 2            chelseaswansea  4391      1 2015-08-08           chelsea
# 3            evertonwatford  4392      1 2015-08-08           everton
# 4       leicestersunderland  4393      1 2015-08-08         leicester
# 5           unitedtottenham  4394      1 2015-08-08            united
# 7            norwichcrystal  4396      1 2015-08-08           norwich
# 0               arsenalwest  4389      1 2015-08-09           arsenal
# 6      newcastlesouthampton  4395      1 2015-08-09         newcastle
# 8            stokeliverpool  4397      1 2015-08-09             stoke
# 9                  bromcity  4398      1 2015-08-10              brom
# 110             villaunited  4499      2 2015-08-14             villa
# 114      southamptoneverton  4503      2 2015-08-15       southampton
# 115       sunderlandnorwich  4504      2 2015-08-15        sunderland
# 116        swanseanewcastle  4505      2 2015-08-15           swansea
# 117          tottenhamstoke  4506      2 2015-08-15         tottenham
# 118             watfordbrom  4507      2 2015-08-15           watford
# 119           westleicester  4508      2 2015-08-15              west
# 111          crystalarsenal  4500      2 2015-08-16           crystal
# 113             citychelsea  4502      2 2015-08-16              city
# 112    liverpoolbournemouth  4501      2 2015-08-17         liverpool
# 229         westbournemouth  4618      3 2015-08-22              west
# 225            norwichstoke  4614      3 2015-08-22           norwich
# 224         unitednewcastle  4613      3 2015-08-22            united
# 226       sunderlandswansea  4615      3 2015-08-22        sunderland
# 221            crystalvilla  4610      3 2015-08-22           crystal
# 223      leicestertottenham  4612      3 2015-08-22         leicester
# 222             evertoncity  4611      3 2015-08-23           everton
# 227      watfordsouthampton  4616      3 2015-08-23           watford
# 228             bromchelsea  4617      3 2015-08-23              brom
# 220        arsenalliverpool  4609      3 2015-08-24           arsenal
# 329        tottenhameverton  4718      4 2015-08-29         tottenham
# 327               stokebrom  4716      4 2015-08-29             stoke
# 325        newcastlearsenal  4714      4 2015-08-29         newcastle
# 324             citywatford  4713      4 2015-08-29              city
# 322          chelseacrystal  4711      4 2015-08-29           chelsea
# 321    bournemouthleicester  4710      4 2015-08-29       bournemouth
# 323           liverpoolwest  4712      4 2015-08-29         liverpool
# 320         villasunderland  4709      4 2015-08-29             villa
# 326      southamptonnorwich  4715      4 2015-08-30       southampton
# 328           swanseaunited  4717      4 2015-08-30           swansea
# 338         bromsouthampton  4727      5 2015-09-12              brom
#
#     away_team_name_id labels res
# 1               villa      A   A
# 2             swansea      D   D
# 3             watford      D   D
# 4          sunderland      H   H
# 5           tottenham      H   H
# 7             crystal      A   A
# 0                west      A   A
# 6         southampton      D   D
# 8           liverpool      A   A
# 9                city      A  AP
# 110            united      A   A
# 114           everton      A  AP
# 115           norwich      A   A
# 116         newcastle      H   H
# 117             stoke      D   D
# 118              brom      D   D
# 119         leicester      A   A
# 111           arsenal      A   A
# 113           chelsea      H  HP
# 112       bournemouth      H   H
# 229       bournemouth      A   A
# 225             stoke      D   D
# 224         newcastle      D   D
# 226           swansea      D   D
# 221             villa      H   H
# 223         tottenham      D   D
# 222              city      A   A
# 227       southampton      D   D
# 228           chelsea      A   A
# 220         liverpool      D   D
# 329           everton      D   D
# 327              brom      A   A
# 325           arsenal      A   A
# 324           watford      H   H
# 322           crystal      A   A
# 321         leicester      D   D
# 323              west      A  AP
# 320        sunderland      D   D
# 326           norwich      H  HP
# 328            united      H   H
# 338       southampton      D   D
# 334         liverpool      H   H
# 337           swansea      H   H
# 331              city      A   A
# 330             stoke      H   H
# 335       bournemouth      H   H
# 332           chelsea      H   H
# 333             villa      H   H
# 336         tottenham      A   A
# 339         newcastle      H   H
# 342           arsenal      H   H
# 340              brom      A   A
# 341        sunderland      H   H
# 348           everton      D   D
# 344              west      A   A
# 345           watford      A   A
# 347         leicester      D   D
# 349           crystal      H   H
# 343           norwich      D   D
# 346            united      A   A
# 350           arsenal      A  AP
# 351             villa      H   H
# 352        sunderland      H  HP
# 353           chelsea      D   D
# 354           swansea      H   H
# 355       bournemouth      H   H
# 356              city      H  HP
# 359           norwich      D   D
# 357           crystal      A   A
# 358           everton      A   A
# 367         leicester      A   A
# 361             stoke      A   A
# 362           watford      D   D
# 363       southampton      A   A
# 364              brom      H   H
# 368              west      D   D
# 366         newcastle      H  HP
# 369         tottenham      D   D
# 360            united      H  HP
# 365         liverpool      D   D
# 378           arsenal      A  AP
# 370             villa      H   H
# 371              west      A   A
# 372            united      A  AP
# 373       bournemouth      H  HP
# 377         liverpool      D   D
# 375         leicester      D   D
# 379        sunderland      H   H
# 374           norwich      H  HP
# 376             stoke      A   A
# 19            chelsea      H   H
# 11            swansea      A   A
# 13            crystal      H   H
# 16               brom      A   A
# 17            watford      A   A
# 10            everton      H   H
# 15               city      D   D
# 14        southampton      D   D
# 12          tottenham      A  AP
# 18          newcastle      H  HP
# 28               west      H   H
# 21             united      D   D
# 23            norwich      H   H
# 26            arsenal      A  AP
# 20          liverpool      A   A
# 29          leicester      A   A
# 24              stoke      D   D
# 22         sunderland      H  HP
# 25        bournemouth      H   H
# 27              villa      H   H
# 32          newcastle      A   A
# 33            watford      H   H
# 39            everton      D   D
# 38        southampton      A   A
# 35               brom      H   H
# 37            chelsea      H   H
# 36            swansea      H   H
# 30          tottenham      D   D
# 31               city      D   D
# 34            crystal      A   A
# 48             united      A   A
# 40            norwich      H   H
# 42              villa      H  HP
# 43          liverpool      A  AP
# 45              stoke      A   A
# 44          leicester      A  AP
# 49            arsenal      H   H
# 46        bournemouth      D   D
# 47               west      H  HP
# 41         sunderland      A   A
# 55        southampton      H   H
# 52          newcastle      H  HP
# 51            everton      D   D
# 50            watford      A   A
# 57              stoke      H   H
# 53             united      D   D
# 54            swansea      H   H
# 56            arsenal      D   D
# 58            chelsea      D   D
# 59               brom      D   D
# 65              villa      D   D
# 63               west      D   D
# 69          tottenham      D   D
# 61        bournemouth      A   A
# 68            norwich      H   H
# 60         sunderland      H   H
# 66               city      H   H
# 67          leicester      A  AP
# 64          liverpool      H   H
# 62            crystal      D   D
# 72        southampton      H   H
# 71             united      H   H
# 77            watford      A   A
# 79              stoke      D   D
# 75            swansea      H   H
# 76            everton      D   D
# 74               brom      D   D
# 78          newcastle      A   A
# 70            arsenal      A   A
# 73            chelsea      H   H
# 85          tottenham      A   A
# 83            norwich      A   A
# 82          leicester      A   A
# 81         sunderland      H   H
# 89        bournemouth      A   A
# 86            crystal      A   A
# 84              villa      D   D
# 87               west      D   D
# 88          liverpool      H  HP
# 80               city      H   H
# 90               west      D   D
# 91            crystal      D   D
# 92            watford      D   D
# 93          leicester      H   H
# 94         sunderland      H  HP
# 95            everton      A   A
# 96            arsenal      H  HP
# 97             united      H   H
# 98               brom      H   H
# 99            norwich      H  HP
# 108         newcastle      H   H
# 109       southampton      H   H
# 107         tottenham      A   A
# 105             villa      H   H
# 101           swansea      D   D
# 102             stoke      A   A
# 100       bournemouth      H   H
# 104           chelsea      D   D
# 103              city      D   D
# 106         liverpool      A   A
# 127              city      A   A
# 129         liverpool      H   H
# 128             stoke      H   H
# 126             villa      H   H
# 120         newcastle      H   H
# 124           swansea      H   H
# 123       bournemouth      D   D
# 125       southampton      H   H
# 122         tottenham      D   D
# 121           chelsea      A  AP
# 130           crystal      H   H
# 131              west      A   A
# 136            united      D   D
# 132        sunderland      A   A
# 133           arsenal      D   D
# 134              brom      D   D
# 135           everton      D   D
# 138           norwich      H   H
# 137           watford      H   H
# 139         leicester      A   A
# 140         leicester      D   D
# 141           norwich      H  HP
# 142           everton      D   D
# 144           crystal      H  HP
# 145              west      H   H
# 146              brom      H  HP
# 149        sunderland      H  HP
# 147           arsenal      D   D
# 143            united      A   A
# 148           watford      H   H
# 153             stoke      H  HP
# 154       southampton      A   A
# 155         liverpool      A   A
# 156       bournemouth      D   D
# 157         newcastle      H   H
# 158             villa      D   D
# 159              city      D   D
# 151         tottenham      A   A
# 150           chelsea      A   A
# 152           swansea      A   A
# 168           swansea      D   D
# 160       southampton      D   D
# 161         liverpool      H   H
# 162         tottenham      A  AP
# 163              city      A   A
# 167             stoke      H  HP
# 165             villa      H   H
# 166       bournemouth      A   A
# 169         newcastle      H  HP
# 164           chelsea      D   D
# 178           crystal      D   D
# 176              west      H   H
# 175              brom      H   H
# 174         leicester      A   A
# 173        sunderland      D   D
# 170           norwich      H   H
# 179           watford      H   H
# 177           everton      A  AP
# 172            united      D   D
# 171           arsenal      A   A
# 189       southampton      A   A
# 188            united      H   H
# 182             stoke      A   A
# 183         newcastle      H  HP
# 184           watford      A   A
# 185              brom      A   A
# 187              west      D   D
# 180         leicester      H   H
# 181         liverpool      A  AP
# 186         tottenham      A   A
# 199        sunderland      H   H
# 190           norwich      H   H
# 198           crystal      H   H
# 194           chelsea      A   A
# 195             villa      H   H
# 197       bournemouth      D   D
# 192           arsenal      H   H
# 196           swansea      H   H
# 203              brom      D   D
# 201           everton      A   A
# 202       southampton      H   H
# 204           chelsea      A   A
# 205           crystal      D   D
# 207              city      H  HP
# 209         newcastle      H   H
# 208           watford      H   H
# 200           swansea      A   A
# 206         tottenham      H   H
# 210             stoke      D   D
# 212              west      A   A
# 213             villa      H  HP
# 214       bournemouth      A   A
# 215        sunderland      D   D
# 216           norwich      H   H
# 217           arsenal      D   D
# 218         leicester      A   A
# 211         liverpool      A   A
# 219            united      H   H
# 232           swansea      H   H
# 237       southampton      A   A
# 236              city      D   D
# 231         tottenham      A   A
# 233         newcastle      H   H
# 240              west      D   D
# 241         leicester      A   A
# 242           arsenal      A   A
# 246             villa      H   H
# 248             stoke      A   A
# 249           norwich      A   A
# 243            united      A   A
# 244        sunderland      D   D
# 245         liverpool      H   H
# 247       bournemouth      H  HP
# 250           watford      H  HP
# 251           chelsea      A  AP
# 252              city      A  AP
# 254         tottenham      D   D
# 256         newcastle      H   H
# 257           swansea      D   D
# 258              brom      D   D
# 259           crystal      D   D
# 253       southampton      H   H
# 255           everton      H   H
# 263              brom      H   H
# 268           everton      D   D
# 269           arsenal      D   D
# 266           chelsea      H   H
# 260       bournemouth      A   A
# 261           norwich      H   H
# 264         newcastle      H   H
# 262             stoke      H  HP
# 265         leicester      A   A
# 267            united      H  HP
# 282           everton      D   D
# 273       southampton      D   D
# 275             villa      H   H
# 276           swansea      H  HP
# 277        sunderland      A  AP
# 279           watford      A   A
# 272              city      A  AP
# 270           crystal      D   D
# 274              west      D   D
# 271         liverpool      A   A
# 278         tottenham      A  AP
# 193              city      D   D
# 235           crystal      H   H
# 239           watford      H   H
# 191           everton      H  HP
# 230              brom      H   H
# 281           chelsea      A  AP
# 280       southampton      A   A
# 284         newcastle      D   D
# 285             stoke      H  HP
# 283           swansea      H  HP
# 287           arsenal      D   D
# 288              brom      D   D
# 299              west      A  AP
# 296        sunderland      D   D
# 298             villa      H   H
# 292       bournemouth      H   H
# 290           norwich      H   H
# 294           crystal      H   H
# 295              city      H   H
# 293         leicester      D   D
# 297         liverpool      H   H
# 291         tottenham      D   D
# 300         newcastle      D   D
# 301              brom      D   D
# 302             stoke      H   H
# 303           everton      H   H
# 309           swansea      A  AP
# 307           chelsea      H   H
# 306            united      A   A
# 305           arsenal      D   D
# 308       southampton      A   A
# 304           watford      H   H
# 289            united      H   H
# 286           watford      H   H
# 234           chelsea      D   D
# 238           everton      H  HP
# 319         liverpool      D   D
# 318        sunderland      D   D
# 317              city      D   D
# 316              west      H   H
# 314         tottenham      H  HP
# 312           norwich      H  HP
# 311         leicester      D   D
# 310             villa      H  HP
# 315           crystal      H  HP
# 313       bournemouth      H   H

# %% [markdown]
# # Creation of the df where the value between teams is going to be our decision value to make clustering

# %%
name_teams = set(df_clustering['home_team_name_id'])

df = pd.DataFrame(columns=name_teams, index= name_teams)
df.head()
# Out:
#           brom liverpool tottenham norwich city villa united chelsea west  \
# brom       NaN       NaN       NaN     NaN  NaN   NaN    NaN     NaN  NaN
# liverpool  NaN       NaN       NaN     NaN  NaN   NaN    NaN     NaN  NaN
# tottenham  NaN       NaN       NaN     NaN  NaN   NaN    NaN     NaN  NaN
# norwich    NaN       NaN       NaN     NaN  NaN   NaN    NaN     NaN  NaN
# city       NaN       NaN       NaN     NaN  NaN   NaN    NaN     NaN  NaN
#
#           swansea sunderland everton arsenal southampton crystal stoke  \
# brom          NaN        NaN     NaN     NaN         NaN     NaN   NaN
# liverpool     NaN        NaN     NaN     NaN         NaN     NaN   NaN
# tottenham     NaN        NaN     NaN     NaN         NaN     NaN   NaN
# norwich       NaN        NaN     NaN     NaN         NaN     NaN   NaN
# city          NaN        NaN     NaN     NaN         NaN     NaN   NaN
#
#           watford newcastle bournemouth leicester
# brom          NaN       NaN         NaN       NaN
# liverpool     NaN       NaN         NaN       NaN
# tottenham     NaN       NaN         NaN       NaN
# norwich       NaN       NaN         NaN       NaN
# city          NaN       NaN         NaN       NaN

# %%
first_clustering = 3
n_clust_end = 3



for i in range(2):
    print(i)
    if i == 0:    
        for team in name_teams:
            df_clustering_teams =df_clustering.loc[df_clustering['home_team_name_id']== team,:]


            ## Remove Rows With Missing Values
            df_clustering_teams.dropna(inplace=True)

            #Remove labels and also the columns that we don't want to use as clustering info
            away_teams =df_clustering_teams['away_team_name_id']
            df_clustering_teams = df_clustering_teams.drop(columns= ['uid','stage','labels','date','id','home_team_name_id','away_team_name_id'])

            df_clustering_teams = convert_to(df_clustering_teams,'onehot', all_categorical = True,columns = 'None')

            #Clustering. We use K =5 because we want to distinct between(H+,H,D,A,A+)
            kmeans = KMeans(n_clusters=first_clustering, random_state=111)
            kmeans.fit(df_clustering_teams)


            #Plotting clustering in pca2 dimensions
            pca = PCA(n_components=2).fit(df_clustering_teams)
            pca_2d = pca.transform(df_clustering_teams)

        #     fig, ax = plt.subplots(figsize=(15,15))
        #     fig.suptitle(f'Home Team: {team}', fontsize=16)
        #     ax.scatter(pca_2d[:, 0], pca_2d[:, 1], c=kmeans.labels_, s=1000)
        #     for i, txt in enumerate(away_teams):
        #         ax.annotate(txt, (pca_2d[i, 0], pca_2d[i, 1]))


            df_clust = pd.DataFrame(columns=['team_away','cluster_labels'])
            df_clust['team_away']= away_teams
            df_clust['cluster_labels']= kmeans.labels_

            #Filling our df with the values we want to use for clustering. In this particular case this values come from a previous clustering.
            for away_team in away_teams:
                df.loc[team,away_team] = df_clust.loc[df_clust['team_away']== away_team,'cluster_labels'].item()



        #Fill NaN values due to teams playing to themselves, or due to first match day.
        df =df.fillna('unknown')

        #We should now transpose the matrix to have as a columns the "performance calculated" of the team in the row playing away against the team in the column playing at home.
        dfT= df.T

        dfT =dfT.astype('category')

        print(dfT.info())

        dfT = convert_to(dfT,'onehot', all_categorical = True,columns = 'None')

        dfT.info()  

        #Now we make the clustering for those rows. This clustering wants to cluster teams that have same caracteristics playing away.
        name_teams = set(dfT.index)



        Sum_of_squared_distances = []
        K = range(1,15)
        for k in K:
            km = KMeans(n_clusters=k)
            km = km.fit(dfT)
            Sum_of_squared_distances.append(km.inertia_)

        fig, ax = plt.subplots(figsize=(15,15))    
        plt.plot(K, Sum_of_squared_distances, 'bx-')
        plt.xlabel('k')
        plt.ylabel('Sum_of_squared_distances')
        plt.title('Elbow Method For Optimal k')
        plt.show()


        kmeans = KMeans(n_clusters=n_clust_end, random_state=111)
        kmeans.fit(dfT)

        pca = PCA(n_components=2).fit(dfT)
        pca_2d = pca.transform(dfT)

        fig, ax = plt.subplots(figsize=(15,15))
        ax.scatter(pca_2d[:, 0], pca_2d[:, 1], c=kmeans.labels_, s=1000)
        

        for i, txt in enumerate(name_teams):
            ax.annotate(txt, (pca_2d[i, 0], pca_2d[i, 1]))
    
        plt.show()
        

        df_cluster = pd.DataFrame(columns=['team_away','cluster_team_away','team_home','cluster_team_home'])
        df_cluster['team_away']= dfT.index
        df_cluster['cluster_team_away']= kmeans.labels_ 
        print(df_cluster)


    elif i ==1:
        for team in name_teams:
            df_clustering_teams =df_clustering.loc[df_clustering['away_team_name_id']== team,:]


            ## Remove Rows With Missing Values
            df_clustering_teams.dropna(inplace=True)

            #Remove labels and also the columns that we don't want to use as clustering info
            away_teams =df_clustering_teams['home_team_name_id']
            df_clustering_teams = df_clustering_teams.drop(columns= ['uid','stage','labels','date','id','home_team_name_id','away_team_name_id'])

            df_clustering_teams = convert_to(df_clustering_teams,'onehot', all_categorical = True,columns = 'None')

            #Clustering. We use K =5 because we want to distinct between(H+,H,D,A,A+)
            kmeans = KMeans(n_clusters=first_clustering, random_state=111)
            kmeans.fit(df_clustering_teams)


            #Plotting clustering in pca2 dimensions
            pca = PCA(n_components=2).fit(df_clustering_teams)
            pca_2d = pca.transform(df_clustering_teams)

        #     fig, ax = plt.subplots(figsize=(15,15))
        #     fig.suptitle(f'Home Team: {team}', fontsize=16)
        #     ax.scatter(pca_2d[:, 0], pca_2d[:, 1], c=kmeans.labels_, s=1000)
        #     for i, txt in enumerate(away_teams):
        #         ax.annotate(txt, (pca_2d[i, 0], pca_2d[i, 1]))


            df_clust = pd.DataFrame(columns=['team_away','cluster_labels'])
            df_clust['team_away']= away_teams
            df_clust['cluster_labels']= kmeans.labels_

            #Filling our df with the values we want to use for clustering. In this particular case this values come from a previous clustering.
            for away_team in away_teams:
                df.loc[team,away_team] = df_clust.loc[df_clust['team_away']== away_team,'cluster_labels'].item()



        #Fill NaN values due to teams playing to themselves, or due to first match day.
        df =df.fillna('unknown')

        #We should now transpose the matrix to have as a columns the "performance calculated" of the team in the row playing away against the team in the column playing at home.
        dfT= df.T

        dfT =dfT.astype('category')

        print(dfT.info())

        dfT = convert_to(dfT,'onehot', all_categorical = True,columns = 'None')

        dfT.info()  

        #Now we make the clustering for those rows. This clustering wants to cluster teams that have same caracteristics playing away.
        name_teams = set(dfT.index)



        Sum_of_squared_distances = []
        K = range(1,15)
        for k in K:
            km = KMeans(n_clusters=k)
            km = km.fit(dfT)
            Sum_of_squared_distances.append(km.inertia_)

        fig, ax = plt.subplots(figsize=(15,15))    
        plt.plot(K, Sum_of_squared_distances, 'bx-')
        plt.xlabel('k')
        plt.ylabel('Sum_of_squared_distances')
        plt.title('Elbow Method For Optimal k')
        plt.show()


        kmeans = KMeans(n_clusters=n_clust_end, random_state=111)
        kmeans.fit(dfT)

        pca = PCA(n_components=2).fit(dfT)
        pca_2d = pca.transform(dfT)

        fig, ax = plt.subplots(figsize=(15,15))
        ax.scatter(pca_2d[:, 0], pca_2d[:, 1], c=kmeans.labels_, s=1000)

        for i, txt in enumerate(name_teams):
            ax.annotate(txt, (pca_2d[i, 0], pca_2d[i, 1]))
            
            
        plt.show()

        print(df_cluster)

        df_cluster['team_home']= dfT.index
        df_cluster['cluster_team_home']= kmeans.labels_   
        print(df_cluster)
# Out:
# 0
# Index(['res'], dtype='object')
# Index(['res'], dtype='object')
# Index(['res'], dtype='object')
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Index(['res'], dtype='object')
# Index(['res'], dtype='object')
# Index(['res'], dtype='object')
# Index(['res'], dtype='object')
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Index(['res'], dtype='object')
# Index(['res'], dtype='object')
# Index(['res'], dtype='object')
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Index(['res'], dtype='object')
# Index(['res'], dtype='object')
# Index(['res'], dtype='object')
# Index(['res'], dtype='object')
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Index(['res'], dtype='object')
# Index(['res'], dtype='object')
# Index(['res'], dtype='object')
# Index(['res'], dtype='object')
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Index(['res'], dtype='object')
# Index(['res'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, brom to leicester
# Data columns (total 20 columns):
# brom           20 non-null category
# liverpool      20 non-null category
# tottenham      20 non-null category
# norwich        20 non-null category
# city           20 non-null category
# villa          20 non-null category
# united         20 non-null category
# chelsea        20 non-null category
# west           20 non-null category
# swansea        20 non-null category
# sunderland     20 non-null category
# everton        20 non-null category
# arsenal        20 non-null category
# southampton    20 non-null category
# crystal        20 non-null category
# stoke          20 non-null category
# watford        20 non-null category
# newcastle      20 non-null category
# bournemouth    20 non-null category
# leicester      20 non-null category
# dtypes: category(20)
# memory usage: 4.9+ KB
# None
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, brom to leicester
# Data columns (total 80 columns):
# brom_0                 20 non-null uint8
# brom_1                 20 non-null uint8
# brom_2                 20 non-null uint8
# brom_unknown           20 non-null uint8
# liverpool_0            20 non-null uint8
# liverpool_1            20 non-null uint8
# liverpool_2            20 non-null uint8
# liverpool_unknown      20 non-null uint8
# tottenham_0            20 non-null uint8
# tottenham_1            20 non-null uint8
# tottenham_2            20 non-null uint8
# tottenham_unknown      20 non-null uint8
# norwich_0              20 non-null uint8
# norwich_1              20 non-null uint8
# norwich_2              20 non-null uint8
# norwich_unknown        20 non-null uint8
# city_0                 20 non-null uint8
# city_1                 20 non-null uint8
# city_2                 20 non-null uint8
# city_unknown           20 non-null uint8
# villa_0                20 non-null uint8
# villa_1                20 non-null uint8
# villa_2                20 non-null uint8
# villa_unknown          20 non-null uint8
# united_0               20 non-null uint8
# united_1               20 non-null uint8
# united_2               20 non-null uint8
# united_unknown         20 non-null uint8
# chelsea_0              20 non-null uint8
# chelsea_1              20 non-null uint8
# chelsea_2              20 non-null uint8
# chelsea_unknown        20 non-null uint8
# west_0                 20 non-null uint8
# west_1                 20 non-null uint8
# west_2                 20 non-null uint8
# west_unknown           20 non-null uint8
# swansea_0              20 non-null uint8
# swansea_1              20 non-null uint8
# swansea_2              20 non-null uint8
# swansea_unknown        20 non-null uint8
# sunderland_0           20 non-null uint8
# sunderland_1           20 non-null uint8
# sunderland_2           20 non-null uint8
# sunderland_unknown     20 non-null uint8
# everton_0              20 non-null uint8
# everton_1              20 non-null uint8
# everton_2              20 non-null uint8
# everton_unknown        20 non-null uint8
# arsenal_0              20 non-null uint8
# arsenal_1              20 non-null uint8
# arsenal_2              20 non-null uint8
# arsenal_unknown        20 non-null uint8
# southampton_0          20 non-null uint8
# southampton_1          20 non-null uint8
# southampton_2          20 non-null uint8
# southampton_unknown    20 non-null uint8
# crystal_0              20 non-null uint8
# crystal_1              20 non-null uint8
# crystal_2              20 non-null uint8
# crystal_unknown        20 non-null uint8
# stoke_0                20 non-null uint8
# stoke_1                20 non-null uint8
# stoke_2                20 non-null uint8
# stoke_unknown          20 non-null uint8
# watford_0              20 non-null uint8
# watford_1              20 non-null uint8
# watford_2              20 non-null uint8
# watford_unknown        20 non-null uint8
# newcastle_0            20 non-null uint8
# newcastle_1            20 non-null uint8
# newcastle_2            20 non-null uint8
# newcastle_unknown      20 non-null uint8
# bournemouth_0          20 non-null uint8
# bournemouth_1          20 non-null uint8
# bournemouth_2          20 non-null uint8
# bournemouth_unknown    20 non-null uint8
# leicester_0            20 non-null uint8
# leicester_1            20 non-null uint8
# leicester_2            20 non-null uint8
# leicester_unknown      20 non-null uint8
# dtypes: uint8(80)
# memory usage: 2.3+ KB
#       team_away  cluster_team_away team_home cluster_team_home
# 0          brom                  1       NaN               NaN
# 1     liverpool                  1       NaN               NaN
# 2     tottenham                  0       NaN               NaN
# 3       norwich                  2       NaN               NaN
# 4          city                  0       NaN               NaN
# 5         villa                  2       NaN               NaN
# 6        united                  2       NaN               NaN
# 7       chelsea                  0       NaN               NaN
# 8          west                  0       NaN               NaN
# 9       swansea                  1       NaN               NaN
# 10   sunderland                  2       NaN               NaN
# 11      everton                  1       NaN               NaN
# 12      arsenal                  1       NaN               NaN
# 13  southampton                  1       NaN               NaN
# 14      crystal                  1       NaN               NaN
# 15        stoke                  1       NaN               NaN
# 16      watford                  1       NaN               NaN
# 17    newcastle                  2       NaN               NaN
# 18  bournemouth                  0       NaN               NaN
# 19    leicester                  0       NaN               NaN
# 1
# Index(['res'], dtype='object')
# Index(['res'], dtype='object')
# Index(['res'], dtype='object')
# Index(['res'], dtype='object')
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Index(['res'], dtype='object')
# Index(['res'], dtype='object')
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Index(['res'], dtype='object')
# Index(['res'], dtype='object')
# Index(['res'], dtype='object')
# Index(['res'], dtype='object')
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Index(['res'], dtype='object')
# Index(['res'], dtype='object')
# Index(['res'], dtype='object')
# Index(['res'], dtype='object')
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Index(['res'], dtype='object')
# Index(['res'], dtype='object')
# Index(['res'], dtype='object')
# Index(['res'], dtype='object')
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Index(['res'], dtype='object')
# Index(['res'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, brom to leicester
# Data columns (total 20 columns):
# brom           20 non-null category
# liverpool      20 non-null category
# tottenham      20 non-null category
# norwich        20 non-null category
# city           20 non-null category
# villa          20 non-null category
# united         20 non-null category
# chelsea        20 non-null category
# west           20 non-null category
# swansea        20 non-null category
# sunderland     20 non-null category
# everton        20 non-null category
# arsenal        20 non-null category
# southampton    20 non-null category
# crystal        20 non-null category
# stoke          20 non-null category
# watford        20 non-null category
# newcastle      20 non-null category
# bournemouth    20 non-null category
# leicester      20 non-null category
# dtypes: category(20)
# memory usage: 4.9+ KB
# None
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# Index(['brom', 'liverpool', 'tottenham', 'norwich', 'city', 'villa', 'united',
#        'chelsea', 'west', 'swansea', 'sunderland', 'everton', 'arsenal',
#        'southampton', 'crystal', 'stoke', 'watford', 'newcastle',
#        'bournemouth', 'leicester'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, brom to leicester
# Data columns (total 80 columns):
# brom_0                 20 non-null uint8
# brom_1                 20 non-null uint8
# brom_2                 20 non-null uint8
# brom_unknown           20 non-null uint8
# liverpool_0            20 non-null uint8
# liverpool_1            20 non-null uint8
# liverpool_2            20 non-null uint8
# liverpool_unknown      20 non-null uint8
# tottenham_0            20 non-null uint8
# tottenham_1            20 non-null uint8
# tottenham_2            20 non-null uint8
# tottenham_unknown      20 non-null uint8
# norwich_0              20 non-null uint8
# norwich_1              20 non-null uint8
# norwich_2              20 non-null uint8
# norwich_unknown        20 non-null uint8
# city_0                 20 non-null uint8
# city_1                 20 non-null uint8
# city_2                 20 non-null uint8
# city_unknown           20 non-null uint8
# villa_0                20 non-null uint8
# villa_1                20 non-null uint8
# villa_2                20 non-null uint8
# villa_unknown          20 non-null uint8
# united_0               20 non-null uint8
# united_1               20 non-null uint8
# united_2               20 non-null uint8
# united_unknown         20 non-null uint8
# chelsea_0              20 non-null uint8
# chelsea_1              20 non-null uint8
# chelsea_2              20 non-null uint8
# chelsea_unknown        20 non-null uint8
# west_0                 20 non-null uint8
# west_1                 20 non-null uint8
# west_2                 20 non-null uint8
# west_unknown           20 non-null uint8
# swansea_0              20 non-null uint8
# swansea_1              20 non-null uint8
# swansea_2              20 non-null uint8
# swansea_unknown        20 non-null uint8
# sunderland_0           20 non-null uint8
# sunderland_1           20 non-null uint8
# sunderland_2           20 non-null uint8
# sunderland_unknown     20 non-null uint8
# everton_0              20 non-null uint8
# everton_1              20 non-null uint8
# everton_2              20 non-null uint8
# everton_unknown        20 non-null uint8
# arsenal_0              20 non-null uint8
# arsenal_1              20 non-null uint8
# arsenal_2              20 non-null uint8
# arsenal_unknown        20 non-null uint8
# southampton_0          20 non-null uint8
# southampton_1          20 non-null uint8
# southampton_2          20 non-null uint8
# southampton_unknown    20 non-null uint8
# crystal_0              20 non-null uint8
# crystal_1              20 non-null uint8
# crystal_2              20 non-null uint8
# crystal_unknown        20 non-null uint8
# stoke_0                20 non-null uint8
# stoke_1                20 non-null uint8
# stoke_2                20 non-null uint8
# stoke_unknown          20 non-null uint8
# watford_0              20 non-null uint8
# watford_1              20 non-null uint8
# watford_2              20 non-null uint8
# watford_unknown        20 non-null uint8
# newcastle_0            20 non-null uint8
# newcastle_1            20 non-null uint8
# newcastle_2            20 non-null uint8
# newcastle_unknown      20 non-null uint8
# bournemouth_0          20 non-null uint8
# bournemouth_1          20 non-null uint8
# bournemouth_2          20 non-null uint8
# bournemouth_unknown    20 non-null uint8
# leicester_0            20 non-null uint8
# leicester_1            20 non-null uint8
# leicester_2            20 non-null uint8
# leicester_unknown      20 non-null uint8
# dtypes: uint8(80)
# memory usage: 2.3+ KB
#       team_away  cluster_team_away team_home cluster_team_home
# 0          brom                  1       NaN               NaN
# 1     liverpool                  1       NaN               NaN
# 2     tottenham                  0       NaN               NaN
# 3       norwich                  2       NaN               NaN
# 4          city                  0       NaN               NaN
# 5         villa                  2       NaN               NaN
# 6        united                  2       NaN               NaN
# 7       chelsea                  0       NaN               NaN
# 8          west                  0       NaN               NaN
# 9       swansea                  1       NaN               NaN
# 10   sunderland                  2       NaN               NaN
# 11      everton                  1       NaN               NaN
# 12      arsenal                  1       NaN               NaN
# 13  southampton                  1       NaN               NaN
# 14      crystal                  1       NaN               NaN
# 15        stoke                  1       NaN               NaN
# 16      watford                  1       NaN               NaN
# 17    newcastle                  2       NaN               NaN
# 18  bournemouth                  0       NaN               NaN
# 19    leicester                  0       NaN               NaN
#       team_away  cluster_team_away    team_home  cluster_team_home
# 0          brom                  1         brom                  2
# 1     liverpool                  1    liverpool                  1
# 2     tottenham                  0    tottenham                  1
# 3       norwich                  2      norwich                  0
# 4          city                  0         city                  1
# 5         villa                  2        villa                  0
# 6        united                  2       united                  1
# 7       chelsea                  0      chelsea                  0
# 8          west                  0         west                  0
# 9       swansea                  1      swansea                  1
# 10   sunderland                  2   sunderland                  0
# 11      everton                  1      everton                  0
# 12      arsenal                  1      arsenal                  1
# 13  southampton                  1  southampton                  1
# 14      crystal                  1      crystal                  0
# 15        stoke                  1        stoke                  2
# 16      watford                  1      watford                  0
# 17    newcastle                  2    newcastle                  2
# 18  bournemouth                  0  bournemouth                  2
# 19    leicester                  0    leicester                  1

# %%
df_cluster
# Out:
#       team_away  cluster_team_away    team_home  cluster_team_home
# 0          brom                  1         brom                  2
# 1     liverpool                  1    liverpool                  1
# 2     tottenham                  0    tottenham                  1
# 3       norwich                  2      norwich                  0
# 4          city                  0         city                  1
# 5         villa                  2        villa                  0
# 6        united                  2       united                  1
# 7       chelsea                  0      chelsea                  0
# 8          west                  0         west                  0
# 9       swansea                  1      swansea                  1
# 10   sunderland                  2   sunderland                  0
# 11      everton                  1      everton                  0
# 12      arsenal                  1      arsenal                  1
# 13  southampton                  1  southampton                  1
# 14      crystal                  1      crystal                  0
# 15        stoke                  1        stoke                  2
# 16      watford                  1      watford                  0
# 17    newcastle                  2    newcastle                  2
# 18  bournemouth                  0  bournemouth                  2
# 19    leicester                  0    leicester                  1

# %%
df_clustering['uid']= df_clustering['home_team_name_id']+df_clustering['away_team_name_id']

# %% [markdown]
# # Let's see if this cluster information alone can give us any useful information

# %%
df_clustering.head()
df_testing_clustering = df_clustering[['uid','labels','home_team_name_id','away_team_name_id','date']]

# %%
def include_cluster_away(team_away,df_cluster):
    clus_away = df_cluster.loc[df_cluster['team_away']==team_away, 'cluster_team_away'].item()
    return clus_away

# %%
def include_cluster_home(team_home,df_cluster):
    clus_home = df_cluster.loc[df_cluster['team_home']==team_home, 'cluster_team_home'].item()
    return clus_home

# %%
df_testing_clustering['cluster_team_away'] = df_testing_clustering.apply(lambda x: include_cluster_away(x['away_team_name_id'], df_cluster), axis =1 )


df_testing_clustering['cluster_team_home'] = df_testing_clustering.apply(lambda x: include_cluster_home(x['home_team_name_id'], df_cluster), axis =1 )
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
df_testing_clustering.head()
# Out:
#                    uid labels home_team_name_id away_team_name_id       date  \
# 1     bournemouthvilla      A       bournemouth             villa 2015-08-08
# 2       chelseaswansea      D           chelsea           swansea 2015-08-08
# 3       evertonwatford      D           everton           watford 2015-08-08
# 4  leicestersunderland      H         leicester        sunderland 2015-08-08
# 5      unitedtottenham      H            united         tottenham 2015-08-08
#
#    cluster_team_away  cluster_team_home
# 1                  2                  2
# 2                  1                  0
# 3                  1                  0
# 4                  2                  1
# 5                  0                  1

# %%
seasons_data = []
for season in seasons:
    seasons_data.append(season.replace('/','_').replace('20',''))

location_to_file = 'data/'
df_testing_clustering.to_csv(location_to_file+f'df_testing_clustering_app5_{n_clust_end}_{leagues_id}_seasons_{seasons_data}.csv',index=False)

# %%
df_clustering.head()
#df_clustering = df_clustering.drop(columns= ['home_team_name_id','away_team_name_id','id','stage'])
df_clustering = df_clustering.drop(columns= ['home_team_name_id','away_team_name_id'])
#df_clustering['dif_goals'] = df_clustering['FTHG']-df_clustering['FTAG']

# %%
df_clustering.to_csv(location_to_file+f'df_FTHG_FTAG_{leagues_id}_seasons_{seasons_data}.csv',index=False)

# %%
df_clustering.head()
# Out:
#                    uid    id  stage       date labels  FTHG  FTAG res
# 1     bournemouthvilla  4390      1 2015-08-08      A   0.0   1.0   A
# 2       chelseaswansea  4391      1 2015-08-08      D   2.0   2.0   D
# 3       evertonwatford  4392      1 2015-08-08      D   2.0   2.0   D
# 4  leicestersunderland  4393      1 2015-08-08      H   4.0   2.0   H
# 5      unitedtottenham  4394      1 2015-08-08      H   1.0   0.0   H

# %%
df_testing_clustering.head()
# Out:
#                    uid labels home_team_name_id away_team_name_id       date  \
# 1     bournemouthvilla      A       bournemouth             villa 2015-08-08
# 2       chelseaswansea      D           chelsea           swansea 2015-08-08
# 3       evertonwatford      D           everton           watford 2015-08-08
# 4  leicestersunderland      H         leicester        sunderland 2015-08-08
# 5      unitedtottenham      H            united         tottenham 2015-08-08
#
#    cluster_team_away  cluster_team_home
# 1                  2                  2
# 2                  1                  0
# 3                  1                  0
# 4                  2                  1
# 5                  0                  1

# %%
import skfuzzy as fuzz
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline



# Set up the loop and plot
fig1, axes1 = plt.subplots(3, 3, figsize=(10, 10))
fpcs = []

for ncenters, ax in enumerate(axes1.reshape(-1), 2):
    cntr, u, u0, d, jm, p, fpc = fuzz.cluster.cmeans(
        df_clustering, ncenters, 2, error=0.005, maxiter=1000, init=None)

    # Store fpc values for later
    fpcs.append(fpc)

    # Plot assigned clusters, for each data point in training set
    cluster_membership = np.argmax(u, axis=0)
    for j in range(ncenters):
        ax.plot(xpts[cluster_membership == j],
                ypts[cluster_membership == j], '.', color=colors[j])

    # Mark the center of each fuzzy cluster
    for pt in cntr:
        ax.plot(pt[0], pt[1], 'rs')

    ax.set_title('Centers = {0}; FPC = {1:.2f}'.format(ncenters, fpc), size=12)
    ax.axis('off')

fig1.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-5c689091045f> in <module>
#      15 for ncenters, ax in enumerate(axes1.reshape(-1), 2):
#      16     cntr, u, u0, d, jm, p, fpc = fuzz.cluster.cmeans(
# ---> 17         df_clustering, ncenters, 2, error=0.005, maxiter=1000, init=None)
#      18
#      19     # Store fpc values for later
#
# /usr/local/lib/python3.7/site-packages/skfuzzy/cluster/_cmeans.py in cmeans(data, c, m, error, maxiter, metric, init, seed)
#     168     while p < maxiter - 1:
#     169         u2 = u.copy()
# --> 170         [cntr, u, Jjm, d] = _cmeans0(data, u2, c, m, metric)
#     171         jm = np.hstack((jm, Jjm))
#     172         p += 1
#
# /usr/local/lib/python3.7/site-packages/skfuzzy/cluster/_cmeans.py in _cmeans0(data, u_old, c, m, metric)
#      24     # Calculate cluster centers
#      25     data = data.T
# ---> 26     cntr = um.dot(data) / np.atleast_2d(um.sum(axis=1)).T
#      27
#      28     d = _distance(data, cntr, metric)
#
# TypeError: can't multiply sequence by non-int of type 'float'
